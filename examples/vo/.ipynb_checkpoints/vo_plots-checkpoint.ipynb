# %%
# Look at the Vo data - households and contact network; add some visualisation of testing over time

# %%
# %matplotlib inline
import numpy as np
import scipy.stats as st
from scipy import sparse
import matplotlib.pyplot as plt
import networkx as nx
import pandas as pd
import sklearn as sk
from sklearn.decomposition import FastICA
from scipy.cluster.hierarchy import dendrogram, linkage

# %%
df = pd.read_csv('./vo_data.csv')
df
# Out:
#             id household_id age_group  fever  fever_temperature  cough  \
# 0     NTdvKuxi     0ccb6352     51-60    NaN                NaN    NaN
# 1     gDKJjToZ     b6e428b2     41-50    NaN                NaN    NaN
# 2     lzTowLhG     6e10a063     00-10    NaN                NaN    NaN
# 3     NUATtRZf     6e10a063     41-50    NaN                NaN    NaN
# 4     ZJripFlV     66a74806     51-60    NaN                NaN    NaN
# 5     qhocbpBY     a59c396d     71-80    NaN                NaN    NaN
# 6     mkYsWMDF     40a9acd9     61-70    NaN                NaN    NaN
# 7     QaiVvPXR     e45171c2     71-80    NaN                NaN    NaN
# 8     hNYnEtRr     4c54830c     21-30    NaN                NaN    NaN
# 9     SRYusUox     de680678     71-80    NaN                NaN    NaN
# 10    WlUQnKkG     b255c94f     51-60    NaN                NaN    NaN
# 11    MHMDhtop     a6e82774     11-20    1.0               38.0    NaN
# 12    XVqfiSOz     a6e82774     00-10    NaN                NaN    NaN
# 13    gLGYwfym     459138f6     51-60    NaN                NaN    NaN
# 14    SWHAlFXh     ed4dd78a     51-60    NaN                NaN    NaN
# 15    zZZJnXaK     b255c94f     51-60    NaN                NaN    NaN
# 16    LedEBhwf     ee8822d3     51-60    NaN                NaN    NaN
# 17    dbzajfMN     6357783c     51-60    NaN                NaN    NaN
# 18    lXJmFsfc     85410f50     51-60    NaN                NaN    NaN
# 19    RXaJbDOL     fda067a8     41-50    NaN                NaN    NaN
# 20    OuXotVDR     a6e82774     41-50    NaN                NaN    NaN
# 21    lRgrsUTu     4c54830c     31-40    NaN                NaN    NaN
# 22    hmfuPJua     17ff623c     81-90    NaN                NaN    NaN
# 23    tJnlxclU     4c54830c     61-70    NaN                NaN    NaN
# 24    FwOeFrQo     65d3ea86     61-70    NaN                NaN    NaN
# 25    NLaNJadG     1de125c7     51-60    NaN                NaN    NaN
# 26    NlxFnxqQ     779d5621     71-80    NaN                NaN    NaN
# 27    hxxRNIQa     84a58264     51-60    NaN                NaN    NaN
# 28    waNCVsSG     f32df557     81-90    NaN                NaN    NaN
# 29    TgUjjcWX     31203707     31-40    1.0               39.5    1.0
# ...        ...          ...       ...    ...                ...    ...
# 2870  YzXbrhuJ     f430b506     21-30    NaN                NaN    NaN
# 2871  lqtdbAwO     0aeaf088       91+    NaN                NaN    NaN
# 2872  OrkNSCjk     0aeaf088     51-60    NaN                NaN    NaN
# 2873  wDSnIJwZ     4ca4897d     51-60    NaN                NaN    NaN
# 2874  iNgMhKnu     2bb23854     11-20    NaN                NaN    NaN
# 2875  RYIzYHfk     19fa3b9e     51-60    NaN                NaN    NaN
# 2876  bAhDSLVz     e91fc92f     41-50    NaN                NaN    NaN
# 2877  FKESVVDZ     55e82941     31-40    NaN                NaN    NaN
# 2878  IBfaRYVF     2bd0495a     71-80    NaN                NaN    NaN
# 2879  RRRpEEbm     752c7f57     31-40    NaN                NaN    NaN
# 2880  cNszxUIw     5adaa746     61-70    NaN                NaN    NaN
# 2881  PvOtJhSi     86ff1281     71-80    NaN                NaN    NaN
# 2882  ImTSPcWc     7ce5633f     00-10    NaN                NaN    NaN
# 2883  oDnwtKjg     7ce5633f     41-50    NaN                NaN    NaN
# 2884  KkQuBWGW     fc4f8bf6     81-90    NaN                NaN    NaN
# 2885  wziMmQvh     58d8f948     51-60    NaN                NaN    NaN
# 2886  KOELxAlg     58d8f948     11-20    NaN                NaN    NaN
# 2887  eTUIyFYd     58d8f948     11-20    NaN                NaN    NaN
# 2888  mgbGUewx     186f10a7     31-40    NaN                NaN    NaN
# 2889  rYojsDgD     b06956e0     51-60    NaN                NaN    NaN
# 2890  wyZvVkCl     f6ea221b     31-40    NaN                NaN    NaN
# 2891  IFYQogYd     11f0d68b     11-20    NaN                NaN    NaN
# 2892  zAnrYmJN     11f0d68b     41-50    NaN                NaN    NaN
# 2893  GDRJZHnp     11f0d68b     11-20    NaN                NaN    NaN
# 2894  wRECVvvA     d5f2d12b     71-80    NaN                NaN    1.0
# 2895  dgINwYWu     e7106745     51-60    NaN                NaN    NaN
# 2896  pRchVltM     43ce0f8f     71-80    NaN                NaN    NaN
# 2897  AhIzCBNu     3f9a9dfc     41-50    NaN                NaN    NaN
# 2898  pFqmFbyF     e7106745     11-20    NaN                NaN    NaN
# 2899  hwbYHdUV     86ff1281     71-80    NaN                NaN    NaN
#
#       sore_throat  malaise  headache  diarrhea  ...  first_sampling  \
# 0             NaN      NaN       1.0       NaN  ...        Negative
# 1             NaN      NaN       NaN       NaN  ...        Negative
# 2             NaN      NaN       NaN       NaN  ...        Negative
# 3             NaN      NaN       NaN       NaN  ...        Negative
# 4             NaN      NaN       NaN       NaN  ...        Negative
# 5             NaN      NaN       NaN       NaN  ...        Negative
# 6             NaN      NaN       NaN       NaN  ...        Negative
# 7             NaN      NaN       NaN       NaN  ...        Negative
# 8             NaN      NaN       NaN       NaN  ...        Negative
# 9             NaN      NaN       NaN       NaN  ...        Negative
# 10            NaN      NaN       NaN       NaN  ...        Negative
# 11            1.0      NaN       NaN       NaN  ...        Negative
# 12            NaN      NaN       NaN       NaN  ...        Negative
# 13            NaN      NaN       NaN       NaN  ...        Negative
# 14            NaN      NaN       NaN       NaN  ...        Negative
# 15            NaN      NaN       NaN       NaN  ...        Negative
# 16            NaN      NaN       NaN       NaN  ...        Negative
# 17            NaN      NaN       NaN       NaN  ...        Negative
# 18            NaN      NaN       NaN       NaN  ...        Negative
# 19            NaN      NaN       NaN       NaN  ...        Negative
# 20            NaN      NaN       NaN       NaN  ...        Negative
# 21            NaN      NaN       NaN       NaN  ...        Negative
# 22            NaN      NaN       NaN       NaN  ...        Negative
# 23            NaN      NaN       NaN       NaN  ...        Positive
# 24            NaN      NaN       NaN       NaN  ...             NaN
# 25            NaN      NaN       NaN       NaN  ...        Negative
# 26            NaN      NaN       NaN       NaN  ...        Negative
# 27            NaN      NaN       NaN       NaN  ...        Negative
# 28            NaN      NaN       NaN       NaN  ...        Negative
# 29            NaN      NaN       NaN       NaN  ...        Negative
# ...           ...      ...       ...       ...  ...             ...
# 2870          NaN      NaN       NaN       NaN  ...        Positive
# 2871          NaN      NaN       NaN       NaN  ...        Negative
# 2872          NaN      NaN       NaN       NaN  ...        Negative
# 2873          NaN      NaN       NaN       NaN  ...        Negative
# 2874          NaN      NaN       NaN       NaN  ...        Negative
# 2875          NaN      NaN       NaN       NaN  ...             NaN
# 2876          NaN      NaN       NaN       NaN  ...        Negative
# 2877          NaN      NaN       NaN       NaN  ...        Negative
# 2878          NaN      NaN       NaN       NaN  ...        Negative
# 2879          NaN      NaN       NaN       NaN  ...        Negative
# 2880          NaN      NaN       NaN       NaN  ...        Negative
# 2881          NaN      NaN       NaN       NaN  ...        Negative
# 2882          NaN      NaN       NaN       NaN  ...        Negative
# 2883          NaN      NaN       NaN       NaN  ...        Negative
# 2884          NaN      NaN       NaN       NaN  ...        Negative
# 2885          NaN      NaN       NaN       NaN  ...        Negative
# 2886          NaN      NaN       NaN       NaN  ...        Negative
# 2887          NaN      NaN       NaN       NaN  ...        Negative
# 2888          NaN      NaN       NaN       NaN  ...        Negative
# 2889          NaN      NaN       NaN       NaN  ...        Negative
# 2890          NaN      NaN       NaN       NaN  ...        Negative
# 2891          NaN      NaN       NaN       NaN  ...        Negative
# 2892          NaN      NaN       NaN       NaN  ...        Negative
# 2893          NaN      NaN       NaN       NaN  ...        Negative
# 2894          NaN      NaN       NaN       NaN  ...        Negative
# 2895          NaN      NaN       NaN       NaN  ...        Negative
# 2896          NaN      NaN       NaN       NaN  ...        Negative
# 2897          NaN      NaN       NaN       NaN  ...        Negative
# 2898          NaN      NaN       NaN       NaN  ...        Negative
# 2899          NaN      NaN       NaN       NaN  ...        Negative
#
#      second_sampling positive  hospitalized  deceased  first_symptoms_date  \
# 0           Negative    False           NaN       NaN                  NaN
# 1           Negative    False           NaN       NaN                  NaN
# 2                NaN    False           NaN       NaN                  NaN
# 3                NaN    False           NaN       NaN                  NaN
# 4           Negative    False           NaN       NaN                  NaN
# 5           Negative    False           NaN       NaN                  NaN
# 6           Negative    False           NaN       NaN                  NaN
# 7           Negative    False           NaN       NaN                  NaN
# 8           Negative    False           NaN       NaN                  NaN
# 9           Negative    False           NaN       NaN                  NaN
# 10          Negative    False           NaN       NaN                  NaN
# 11          Negative    False           NaN       NaN                  NaN
# 12          Negative    False           NaN       NaN                  NaN
# 13          Negative    False           NaN       NaN                  NaN
# 14          Negative    False           NaN       NaN                  NaN
# 15          Negative    False           NaN       NaN                  NaN
# 16          Negative    False           NaN       NaN                  NaN
# 17          Negative    False           NaN       NaN                  NaN
# 18          Negative    False           NaN       NaN                  NaN
# 19          Negative    False           NaN       NaN                  NaN
# 20          Negative    False           NaN       NaN                  NaN
# 21          Negative    False           NaN       NaN                  NaN
# 22          Negative    False           NaN       NaN                  NaN
# 23          Negative     True           NaN        NO                  NaN
# 24          Negative    False           NaN       NaN                  NaN
# 25          Negative    False           NaN       NaN                  NaN
# 26               NaN    False           NaN       NaN                  NaN
# 27          Negative    False           NaN       NaN                  NaN
# 28          Negative    False           NaN       NaN                  NaN
# 29          Negative    False           NaN       NaN                  NaN
# ...              ...      ...           ...       ...                  ...
# 2870             NaN     True           NaN        NO                  NaN
# 2871             NaN    False           NaN       NaN                  NaN
# 2872        Negative    False           NaN       NaN                  NaN
# 2873        Negative    False           NaN       NaN                  NaN
# 2874        Negative    False           NaN       NaN                  NaN
# 2875        Negative    False           NaN       NaN                  NaN
# 2876             NaN    False           NaN       NaN                  NaN
# 2877             NaN    False           NaN       NaN                  NaN
# 2878             NaN    False           NaN       NaN                  NaN
# 2879        Negative    False           NaN       NaN                  NaN
# 2880        Negative    False           NaN       NaN                  NaN
# 2881        Negative    False           NaN       NaN                  NaN
# 2882        Negative    False           NaN       NaN                  NaN
# 2883        Negative    False           NaN       NaN                  NaN
# 2884        Negative    False           NaN       NaN                  NaN
# 2885        Negative    False           NaN       NaN                  NaN
# 2886        Negative    False           NaN       NaN                  NaN
# 2887        Negative    False           NaN       NaN                  NaN
# 2888        Negative    False           NaN       NaN                  NaN
# 2889        Negative    False           NaN       NaN                  NaN
# 2890             NaN    False           NaN       NaN                  NaN
# 2891        Negative    False           NaN       NaN                  NaN
# 2892        Negative    False           NaN       NaN                  NaN
# 2893        Negative    False           NaN       NaN                  NaN
# 2894             NaN    False           NaN       NaN                  NaN
# 2895        Negative    False           NaN       NaN                  NaN
# 2896        Negative    False           NaN       NaN                  NaN
# 2897        Negative    False           NaN       NaN                  NaN
# 2898        Negative    False           NaN       NaN                  NaN
# 2899        Negative    False           NaN       NaN                  NaN
#
#       clinical_condition_at_hospitalization  first_hospitalization_date  \
# 0                                       NaN                         NaN
# 1                                       NaN                         NaN
# 2                                       NaN                         NaN
# 3                                       NaN                         NaN
# 4                                       NaN                         NaN
# 5                                       NaN                         NaN
# 6                                       NaN                         NaN
# 7                                       NaN                         NaN
# 8                                       NaN                         NaN
# 9                                       NaN                         NaN
# 10                                      NaN                         NaN
# 11                                      NaN                         NaN
# 12                                      NaN                         NaN
# 13                                      NaN                         NaN
# 14                                      NaN                         NaN
# 15                                      NaN                         NaN
# 16                                      NaN                         NaN
# 17                                      NaN                         NaN
# 18                                      NaN                         NaN
# 19                                      NaN                         NaN
# 20                                      NaN                         NaN
# 21                                      NaN                         NaN
# 22                                      NaN                         NaN
# 23                                      NaN                         NaN
# 24                                      NaN                         NaN
# 25                                      NaN                         NaN
# 26                                      NaN                         NaN
# 27                                      NaN                         NaN
# 28                                      NaN                         NaN
# 29                                      NaN                         NaN
# ...                                     ...                         ...
# 2870                                    NaN                         NaN
# 2871                                    NaN                         NaN
# 2872                                    NaN                         NaN
# 2873                                    NaN                         NaN
# 2874                                    NaN                         NaN
# 2875                                    NaN                         NaN
# 2876                                    NaN                         NaN
# 2877                                    NaN                         NaN
# 2878                                    NaN                         NaN
# 2879                                    NaN                         NaN
# 2880                                    NaN                         NaN
# 2881                                    NaN                         NaN
# 2882                                    NaN                         NaN
# 2883                                    NaN                         NaN
# 2884                                    NaN                         NaN
# 2885                                    NaN                         NaN
# 2886                                    NaN                         NaN
# 2887                                    NaN                         NaN
# 2888                                    NaN                         NaN
# 2889                                    NaN                         NaN
# 2890                                    NaN                         NaN
# 2891                                    NaN                         NaN
# 2892                                    NaN                         NaN
# 2893                                    NaN                         NaN
# 2894                                    NaN                         NaN
# 2895                                    NaN                         NaN
# 2896                                    NaN                         NaN
# 2897                                    NaN                         NaN
# 2898                                    NaN                         NaN
# 2899                                    NaN                         NaN
#
#       discharge_date  death_date
# 0                NaN         NaN
# 1                NaN         NaN
# 2                NaN         NaN
# 3                NaN         NaN
# 4                NaN         NaN
# 5                NaN         NaN
# 6                NaN         NaN
# 7                NaN         NaN
# 8                NaN         NaN
# 9                NaN         NaN
# 10               NaN         NaN
# 11               NaN         NaN
# 12               NaN         NaN
# 13               NaN         NaN
# 14               NaN         NaN
# 15               NaN         NaN
# 16               NaN         NaN
# 17               NaN         NaN
# 18               NaN         NaN
# 19               NaN         NaN
# 20               NaN         NaN
# 21               NaN         NaN
# 22               NaN         NaN
# 23               NaN         NaN
# 24               NaN         NaN
# 25               NaN         NaN
# 26               NaN         NaN
# 27               NaN         NaN
# 28               NaN         NaN
# 29               NaN         NaN
# ...              ...         ...
# 2870             NaN         NaN
# 2871             NaN         NaN
# 2872             NaN         NaN
# 2873             NaN         NaN
# 2874             NaN         NaN
# 2875             NaN         NaN
# 2876             NaN         NaN
# 2877             NaN         NaN
# 2878             NaN         NaN
# 2879             NaN         NaN
# 2880             NaN         NaN
# 2881             NaN         NaN
# 2882             NaN         NaN
# 2883             NaN         NaN
# 2884             NaN         NaN
# 2885             NaN         NaN
# 2886             NaN         NaN
# 2887             NaN         NaN
# 2888             NaN         NaN
# 2889             NaN         NaN
# 2890             NaN         NaN
# 2891             NaN         NaN
# 2892             NaN         NaN
# 2893             NaN         NaN
# 2894             NaN         NaN
# 2895             NaN         NaN
# 2896             NaN         NaN
# 2897             NaN         NaN
# 2898             NaN         NaN
# 2899             NaN         NaN
#
# [2900 rows x 133 columns]

# %%
for x in df.columns[104:123]:
    print(x)
# Out:
# 21/02/2020
# 22/02/2020
# 23/02/2020
# 24/02/2020
# 25/02/2020
# 26/02/2020
# 27/02/2020
# 28/02/2020
# 29/02/2020
# 01/03/2020
# 02/03/2020
# 03/03/2020
# 04/03/2020
# 05/03/2020
# 06/03/2020
# 07/03/2020
# 08/03/2020
# 09/03/2020
# 10/03/2020

# %%
posi = ((df['first_sampling'].values == 'Positive') | (df['second_sampling'].values == 'Positive'))

# %%
# indices taken from the vo_legend file
symptom_indices = range(3,13)
contact_indices = range(13,104)
testday_indices = range(104,123)

# %%
hcol = df.household_id.values
hhids = pd.unique(df.household_id)
len(hhids)
# Out:
# 1299

# %%
hh_tests = []
ages = []
for hid in hhids:
    dfh = df[df.household_id == hid]
    tests = dfh.iloc[:,testday_indices].values
    aa = dfh.iloc[:,2].values
    tests[tests=='Neg'] = 0
    tests[tests=='Pos'] = 1
    hh_tests.append(tests)
    ages.append(aa)

# %%
age_gs = pd.unique(df.age_group)
age_gs.sort()
age_gs
# Out:
# array(['00-10', '11-20', '21-30', '31-40', '41-50', '51-60', '61-70',
#        '71-80', '81-90', '91+'], dtype=object)

# %%
nsamp = np.zeros(len(age_gs))
npos = np.zeros(len(age_gs))

# %%
for i, ag in enumerate(age_gs):
    dfa = df[df.age_group == ag]
    nsamp[i] = len(dfa)
    dfp = df[posi]
    dfa = dfp[dfp.age_group == ag]
    npos[i] = len(dfa)

# %%
plt.bar(np.arange(0,len(nsamp)),nsamp)
# Out:
# <BarContainer object of 10 artists>

# %%
plt.bar(np.arange(0,len(npos)),npos)
# Out:
# <BarContainer object of 10 artists>

# %%
plt.bar(np.arange(0,len(npos)),npos/nsamp)
# Out:
# <BarContainer object of 10 artists>

# %%
# Dictionary that puts ages in categories
as2rg = {
    '00-10' : 1,
    '11-20' : 1,
    '21-30' : 0, # 0 is reference class
    '31-40' : 0,
    '41-50' : 0,
    '51-60' : 2,
    '61-70' : 3,
    '71-80' : 4,
    '81-90' : 5,
    '91+'   : 5,
}

# %%
nages = max(as2rg.values())

# %%
Y = [] # To store outcomes
XX = [] # To store design matrices
for i in range(0,len(hhids)):
    mya = [as2rg[a] for a in ages[i]]
    m = len(mya)
    myx = np.zeros((m,nages))
    myy = np.zeros(m)
    for j, a in enumerate(mya):
        if (a>0):
            myx[j,a-1] = 1
        if (np.any(hh_tests[i][j,:]==1)):
            myy[j] = 1
    Y.append(myy)
    XX.append(myx)

# %%
k=0
plt.figure(figsize=(18,20))
for j in range(0,len(hh_tests)):
    tests = hh_tests[j]
    nn, tt = tests.shape
    if ((tests[tests==1]).size > 0):
        #print(tests)
        k+=1
        plt.subplot(10,6,k)
        for y in range(0,nn):
            for t in range(0,tt):
                if (tests[y,t] == 1):
                    plt.plot(t,y,marker='+',c='r')
                elif (tests[y,t] == 0):
                    plt.plot(t,y,marker='o',c='b')
                else:
                    plt.plot(t,y,marker='.',c='k')
        plt.ylim([-0.5, nn-0.5]) 
        plt.yticks(np.arange(0,nn),ages[j])
plt.tight_layout()

# %%
itxt = df.id.values
jtxt = df.columns.values[contact_indices]
ii = range(1,len(itxt)+1)
t2i = dict(zip(itxt,ii)) # this will be a dictionary storing lookup from code to node

# %%
k = len(t2i) # This will count the number of nodes
IJ = [] # This is for import into networkx
for jt in jtxt:
    if jt in t2i.keys():
        j = t2i[jt]
    else:
        k += 1
        t2i[jt] = k
        j = k
    traced = df[jt].values
    for i in np.where(~np.isnan(traced))[0]:
        IJ.append((j, i))
I = range(1,k+1)

# %%
DG = nx.DiGraph()
DG.add_nodes_from(I)
DG.add_edges_from(IJ)

# %%
c = []
for i in range(0,k):
    if (i < len(itxt)):
        if (not posi[i]):
            c.append('b')
        else:
            c.append('r')
    else:
        c.append('r')

# %%
# TO DO: Check if these indicate shared contacts by 
plt.figure(figsize=(10,10))
pos=nx.spring_layout(DG)
nx.draw_networkx(DG,pos,with_labels=False,node_size=10,node_color=c)
plt.savefig('./vonet.pdf',format='pdf')

# %%
hsize = []
hpos = []
for hh in hhids:
    jj = np.argwhere(hcol == hh)
    hsize.append(len(jj[:,0]))
    hpos.append(sum(posi[jj[:,0]]))
hsize = np.array(hsize)
hpos = np.array(hpos)

# %%
plt.hist(hsize[hsize<10.0],np.arange(0.5,10.5)) # Plot shows Look at 6+
# Out:
# (array([444., 425., 230., 165.,  21.,   7.,   2.,   2.,   0.]),
#  array([0.5, 1.5, 2.5, 3.5, 4.5, 5.5, 6.5, 7.5, 8.5, 9.5]),
#  <a list of 9 Patch objects>)

# %%
q = np.sum(hpos)/np.sum(hsize)
q
# Out:
# 0.02620689655172414

# %%
plt.figure(figsize=(6,8))
for i in range(1,6):
    plt.subplot(3,2,i)
    yy = hpos[hsize==i]
    xx = np.arange(0,i+1)
    zz = st.binom.pmf(xx,i,q)
    plt.scatter(xx,zz,zorder=2,c='w',s=60)
    plt.scatter(xx,zz,zorder=3,c='b',s=40)
    plt.hist(yy,bins=np.arange(-0.5,i+1.0,1),color='r',density=True,zorder=1)
    plt.xticks(range(0,i+1))
    plt.ylim([0,0.15])
    plt.xlabel('Swab Positives')
    plt.ylabel('Proportion')
    plt.title('Household Size ' + str(i))

plt.subplot(3,2,6)
yy = hpos[hsize>=6]
xx = np.arange(0,7)
zz = st.binom.pmf(xx,i,q)
plt.scatter(xx,zz,zorder=2,c='w',s=60)
plt.scatter(xx,zz,zorder=3,c='b',s=40)
plt.hist(yy,bins=np.arange(-0.5,7.0,1),color='r',density=True,zorder=1)
plt.xticks(range(0,7))
plt.ylim([0,0.15])
plt.xlabel('Swab Positives')
plt.ylabel('Proportion')
plt.title('Household Size 6+')

plt.tight_layout()

#plt.savefig('./vohh.pdf',format='pdf')

# %%
df_pos_symp = df[posi].iloc[:,symptom_indices]
symps = ['fever','cough','sore_throat','malaise','diarrhea','conjunctivitis','other_symptoms']
symp_names = ['Fever','Cough','Sore Throat','Malaise','Diarrhoea','Conjunctivitis','Rhinitis']
print(pd.unique(df_pos_symp.other_symptoms))
Xtxt = df_pos_symp[symps].values
# Out:
# [nan 'rhinitis']

# %%
X = Xtxt.copy()
X[pd.isna(X)] = 0.0
X[X=='rhinitis'] = 1.0
X = X.astype(np.float)

# %%
# This is linkage by symptoms on cases not linkage of symptoms
W = linkage(X.T, 'ward')
plt.figure(figsize=(6,8))
dendrogram(W,labels=np.array(symp_names), leaf_rotation=90)
plt.tight_layout()
#plt.savefig('./vo_symptoms.pdf')

# %%
myica = FastICA(n_components=2, random_state=33)
myica.fit(X)
# Out:
# FastICA(algorithm='parallel', fun='logcosh', fun_args=None, max_iter=200,
#         n_components=2, random_state=33, tol=0.0001, w_init=None, whiten=True)

# %%
n, p = X.shape

# %%
vv = myica.components_
Z = X@(vv.T)

# %%
U = np.eye(p)@(vv.T)

# %%
plt.figure(figsize=(6,6))
plt.scatter(Z[:,0],Z[:,1], c='b', s=80, alpha=0.3) # Does look a bit like no symptoms and three clusters
for i in range(0,p):
    #plt.plot(np.array([0.0, U[i,0]]),np.array([0.0, U[i,1]]))
    plt.annotate(symp_names[i],np.zeros(2),xytext=U[i,:],arrowprops={'arrowstyle':'->'})
plt.xlabel('IC 1')
plt.ylabel('IC 2')
plt.tight_layout()
#plt.savefig('./vo_ica.pdf')
